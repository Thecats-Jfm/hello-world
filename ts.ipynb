# %%
a = input()
try :
    a = int(a)
except (ValueError):
    print("not a number")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# &lt;ipython-input-10-bc68cfd9e645&gt; in &lt;module&gt;
#       2 try :
# ----&gt; 3     a = int(a)
#       4 except (ValueError, e):
#
# ValueError: invalid literal for int() with base 10: &#39;aaaa12310.0&#39;
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# &lt;ipython-input-10-bc68cfd9e645&gt; in &lt;module&gt;
#       2 try :
#       3     a = int(a)
# ----&gt; 4 except (ValueError, e):
#       5     print(e)
#       6
#
# NameError: name &#39;e&#39; is not defined

# %%
#!/usr/bin/python3
import random
user = 0
time = -1
"""
-1:random
1(computer last win):(computer --)
0(cpmouter last lost or draw):(computer ++)
from <<Socialcycling and conditional responses in the Rock-Paper-Scissors Game>>
"""
while True:
    try:
        user_raw = input("Please input: scissors(0), rock(1), paper(2) or Quit(3):")
        user = int(user_raw)
        if user == 3:
            break
        if time ==-1:
            computer = random.randint(0,2)
        elif time ==1:
            computer = (computer-1+3)%3
        else :
            computer = (computer+1)%3
        print("You:",user," Computer:",computer);
        if(user == 0 and computer == 2) or (user == 1 and computer == 0) or (user == 2 and computer ==1):
            print("You Win!")
        elif computer==user:
            print("Draw!")
        else:
            print("You Lost.")
    except(ValueError):
        print("Please input a number.")
# Out:
# You: 1  Computer: 1
# Draw!
# You: 5  Computer: 2
# You Lost.
# You: 0  Computer: 0
# Draw!
# Please input a number.
# Please input a number.
# You: 1  Computer: 1
# Draw!
# Please input a number.
# You: 2  Computer: 1
# You Win!
# Please input a number.
# Please input a number.
